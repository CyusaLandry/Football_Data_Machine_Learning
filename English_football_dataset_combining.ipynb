# %% [markdown]
# import pandas,numpy and os which will help find the folder of my csv files and combine them together

# %%
import pandas as pd
import numpy as np
import os 
folder_path = 'D:\Big Data\Final Exam\Final folder\datasets' 
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]
csv_files.sort()

# %% [markdown]
# Combine all csvs into a single dataset

# %%
combined_df = pd.concat(
    [pd.read_csv(os.path.join(folder_path, file)) for file in csv_files],
    ignore_index=True
)

# Save the result to a new CSV file
combined_df.to_csv('english_football_data.csv', index=False)

print(f" Combined {len(csv_files)} files into 'combined_output.csv'")
combined_df.head()
# Out:
#  Combined 27 files into 'combined_output.csv'
#   Div      Date        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E0  13/08/16         Burnley     Swansea     0     1   A   0.0   0.0   D
# 1  E0  13/08/16  Crystal Palace   West Brom     0     1   A   0.0   0.0   D
# 2  E0  13/08/16         Everton   Tottenham     1     1   D   1.0   0.0   H
# 3  E0  13/08/16            Hull   Leicester     2     1   H   1.0   0.0   H
# 4  E0  13/08/16        Man City  Sunderland     2     1   H   1.0   0.0   H
#
#    ... 1XBCH  1XBCD  1XBCA  BFECH  BFECD  BFECA  BFEC>2.5  BFEC<2.5  BFECAHH  \
# 0  ...   NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN      NaN
# 1  ...   NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN      NaN
# 2  ...   NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN      NaN
# 3  ...   NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN      NaN
# 4  ...   NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN      NaN
#
# ...
